# %%
#Python 101

# %% [markdown]
# ## Data TYPE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Numeric

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num=100

# %%
type(num)
# Out:
# int

# %%
num % 3
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cnum = 5+7j

# %%
type(cnum)
# Out:
# complex

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Logical opperators
1. And
2. Or
3. Not
# Out:
#   File "<ipython-input-2-52ffdfabddaf>", line 2
#     1. And
#        ^
# SyntaxError: invalid syntax

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
Not True
# Out:
#   File "<ipython-input-5-a4d926873219>", line 1
#     Not True
#         ^
# SyntaxError: invalid syntax

# %%
not True
# Out:
# False

# %%
# Lets define two variables having boolean values True and False-
START = True
STOP = False

# Print the values as it is
print(f"Defined value of START = {START}")
print(f"Defined value of STOP = {STOP} \n")

# if can also be written as -
print(f"Defined value of START = {START}")
print(f"Value of STOP by negating START= {not START} \n")

# alternatively -
print(f"Value of START by negating STOP = {not STOP}")
print(f"Defined value of STOP = {STOP} \n")
# Out:
# Defined value of START = True
# Defined value of STOP = False
#
# Defined value of START = True
# Value of STOP by negating START= False
#
# Value of START by negating STOP = True
# Defined value of STOP = False

# %%
not bool(0)
# Out:
# True

# %%
not int(bool(0))
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
int(bool(1))
# Out:
# 1

# %%
START = 1
STOP = 0

# Print the values as it is
print(f"Defined value of START = {START}")
print(f"Defined value of STOP = {STOP} \n")

# if can also be written as -
print(f"Defined value of START = {START}")
print(f"Value of STOP by negating START= {int(not START)} \n")

# alternatively -
print(f"Value of START by negating STOP = {int(not STOP)}")
print(f"Defined value of STOP = {STOP} \n")
# Out:
# Defined value of START = 1
# Defined value of STOP = 0
#
# Defined value of START = 1
# Value of STOP by negating START= 0
#
# Value of START by negating STOP = 1
# Defined value of STOP = 0

# %%
not 2
# Out:
# False

# %%
not 3
# Out:
# False

# %%
not 5
# Out:
# False

# %%
# any number other than o will be false

# %%
not -1
# Out:
# False

# %%
a=5

# %%
b=5

# %%
bool(a)
# Out:
# True

# %%
not bool(a)
# Out:
# False

# %%
bool(b)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %% [markdown]
# #Logical And

# %%
not(False) * True
# Out:
# True

# %%
False * (not(False))
# Out:
# 0

# %%
not(True) * False
# Out:
# True

# %%
False * False
# Out:
# 0

# %%
not False * False
# Out:
# True

# %%
not(1)
# Out:
# False

# %%
# precedence operation
#bodmas rule

# %%
1+2
# Out:
# 3

# %%
1+2*3
# Out:
# 7

# %%
(1+2)*3
# Out:
# 9

# %% [markdown]
# ### 4.1.2 Equality Operators
#
# Following operations are present in python for equlity check operation-
#
# |Operators|Meaning|
# |-|-|
# |**is**|***a is b*** returns true if variable/identifiers a and b *points* to the *same object*|
# |**is not**|***a is not b*** returns true if variable/identifiers a and b *points* to the *different object*|
# |**==**|***a == b*** returns true if variable/identifiers a and b has same value|
# |**!=**|***a != b*** returns true if variable/identifiers a and b has different value|

# %%
lst_a=[1,2,3,4]
lst_b=[1,2,3,4]

# %%
# get location in memory
id(lst_a)
# Out:
# 133319325416384

# %%
print(id(lst_a))
print(id(lst_b))
# Out:
# 133319325416384
# 133318467966144

# %%
str="Parth"
str2="Parth"

# %%
id(str)
# Out:
# 133318469607280

# %%
id(str2)
# Out:
# 133318469607280

# %%
## what is the difference
String --> 1 Value
Numeric --> collection
# Out:
#   File "<ipython-input-45-b1ef90f82701>", line 2
#     String --> 1 Value
#             ^
# SyntaxError: invalid syntax

# %%
lst_a
# Out:
# [1, 2, 3, 4]

# %%
lst_a[0]
# Out:
# 1

# %%
lst_a[0] =10

# %%
lst_a
# Out:
# [10, 2, 3, 4]

# %%
str1 ="Parth"

# %%
str1[0]
# Out:
# 'P'

# %%
str[0] ="I"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-25fdf375c0da> in <cell line: 1>()
# ----> 1 str[0] ="I"
#
# TypeError: 'str' object does not support item assignment

# %%
# STRINGS ARE IMMUTABLE

# %% [markdown]
# |Operation|Meaning|
# |:-:|:-:|
# | **<** |less than|
# | **<=** |less than or equal to|
# | **>** |greater than|
# | **>=** |greater than or equal to|

# %% [markdown]
# ## Arithmethic Operations
# |Operation|Meaning|
# |:-:|:-:|
# | **+** |addition|
# | **-** |subtraction|
# | **\*** |multiplication|
# | **/** |true division|
# | **//** |integer division|
# | **%** |the modulo operator|

# %% [markdown]
# ### Bitwise Operators
# |Operation|Meaning|
# |:-:|:-:|
# | **∼** |bitwise complement (prefix unary operator)|
# | **&** |bitwise and|
# | **\|** |bitwise or|
# | **^** |bitwise exclusive-or|
# | **<<** |shift bits left, filling in with zeros|
# | **>>** |shift bits right, filling in with sign bit|

# %%
# bitwise is not important for course

# %% [markdown]
# ## Arithmethic Operations
# |Operation|Meaning|
# |:-:|:-:|
# | **+** |addition|
# | **-** |subtraction|
# | **\*** |multiplication|
# | **/** |true division|
# | **//** |integer division|
# | **%** |the modulo operator|

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"Welcome to Data sci"
# Out:
# 'Welcome to Data sci'

# %%
str1="Welcome to Data Science Masters"

# %%
type(str1)
# Out:
# str

# %%
## immutable
str1[0]=12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-de6b3c967f41> in <cell line: 2>()
#       1 ## immutable
# ----> 2 str1[0]=12
#
# TypeError: 'str' object does not support item assignment

# %%
# can i change string with something else
str1="Krish Naik"

# %%
# can i iterate in string? - Yes

# %%
welcome="Hello World"

# %%
str = 'My name is Parth'

# %%
dir(welcome)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
## Inbuild function
# dont by heart.. Just understand

# %%
string ="Pw Skills Data Science"

# %%
string[5]
# Out:
# 'i'

# %%
# slice operation
string[5:]
# Out:
# 'ills Data Science'

# %%
## slice operation
string[5:11]

# it will count space and till 10
# Out:
# 'ills D'

# %%
string[-1]
# Out:
# 'e'

# %%
string[-1:]
# Out:
# 'e'

# %%
string[-3:]
# Out:
# 'nce'

# %%
string[-7:-3]
# Out:
# 'Scie'

# %%
# explain why this will not work
string[7:5]
# Out:
# ''

# %%
## read everything except last
string[:-1]
# Out:
# 'Pw Skills Data Scienc'

# %%
# read everything
string[:]
# Out:
# 'Pw Skills Data Science'

# %%
type(str)
# Out:
# str

# %%
# reverse string

# %%
string[::]
# Out:
# 'Pw Skills Data Science'

# %%
string[::-1]
# Out:
# 'ecneicS ataD sllikS wP'

# %%
# every second element
string[::-2]
# Out:
# 'eniSaa liSw'

# %%
course_name="Data Science Masters"

# %%
## concatentaion

course_name + "Course"
# Out:
# 'Data Science MastersCourse'

# %%
print("Hello" + "Worlds")
# Out:
# HelloWorlds

# %%
course_name *5
# Out:
# 'Data Science MastersData Science MastersData Science MastersData Science MastersData Science Masters'

# %%
len(course_name)
# Out:
# 20

# %%
## find function
course_name.find("n")
# Out:
# 9

# %%
course_name[9]
# Out:
# 'n'

# %%
## count()
course_name.count('a')
# Out:
# 3

# %%
course_name.count(' ')
# Out:
# 2

# %%
course_name
# Out:
# 'Data Science Masters'

# %%
course_name[::-1]
# Out:
# 'sretsaM ecneicS ataD'

# %%
## Split func

# %%
course_name.split(' ')
# Out:
# ['Data', 'Science', 'Masters']

# %%
course_name.split('e')
# Out:
# ['Data Sci', 'nc', ' Mast', 'rs']

# %%
## SString upper and lowercase
course_name.upper()
# Out:
# 'DATA SCIENCE MASTERS'

# %%
course_name.lower()
# Out:
# 'data science masters'

# %%
course_name.swapcase()
# Out:
# 'dATA sCIENCE mASTERS'

# %%
## Assignments
size = int(input("Enter the triangle Length:"))
for i in range(size):
    for j in range(size-i):
        print("",end=" ")
    for k in range(i+1) :
        print("*",end="")
    for m in range(k-1):
        print("*", end="")
    print()
# Out:
# Enter the triangle Length:12
#             *
#            **
#           ****
#          ******
#         ********
#        **********
#       ************
#      **************
#     ****************
#    ******************
#   ********************
#  **********************

# %%
## List is collection

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (1,2,3,4,45,45.45 , 45+7j , "sudh" , True)

# %%
type(t1)
# Out:
# tuple

# %%
l = [1,2,3,4]

# %%
type(l)
# Out:
# list

# %%
t1
# Out:
# (1, 2, 3, 4, 45, 45.45, (45+7j), 'sudh', True)

# %%
t1[0]
# Out:
# 1

# %%
t1[::-1]
# Out:
# (True, 'sudh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
t1.count(4)
# Out:
# 1

# %%
# slicing operation

# %%
t1[0:3]
# Out:
# (1, 2, 3)

# %%
# difff  -tuple only 2 method (shift+tab)

# %%
#System will save value of true as 1
t1.index(1)
# Out:
# 0

# %%
t1.count(True)
# Out:
# 2

# %%
t1.index('sudh')
# Out:
# 7

# %%
## immutable

# %%
t1[0] = 345
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-f5a7769252f6> in <cell line: 1>()
# ----> 1 t1[0] = 345
#
# TypeError: 'tuple' object does not support item assignment

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l[0]
# Out:
# 1

# %%
l[0] = 100

# %%
## item assignment and immutablity are different

# %%
t1
# Out:
# (1, 2, 3, 4, 45, 45.45, (45+7j), 'sudh', True)

# %%
for i in t1 :
    print(i , type(i))
# Out:
# 1 <class 'int'>
# 2 <class 'int'>
# 3 <class 'int'>
# 4 <class 'int'>
# 45 <class 'int'>
# 45.45 <class 'float'>
# (45+7j) <class 'complex'>
# sudh <class 'str'>
# True <class 'bool'>

# %%
t2 = (1,2,3,3,4)

# %%
t2
# Out:
# (1, 2, 3, 3, 4)

# %%
t2 * 3
# Out:
# (1, 2, 3, 3, 4, 1, 2, 3, 3, 4, 1, 2, 3, 3, 4)

# %%
max(t2)
# Out:
# 4

# %%
min(t2)
# Out:
# 1

# %%
t1 = (1,2,32,4)
t2 = (4,5,6,7,8)

# %%
t3 = (t1,t2)

# %%
t3
# Out:
# ((1, 2, 32, 4), (4, 5, 6, 7, 8))

# %%
t4 = ((1,2,3,4,5) , [1,3,5,6,7,8])

# %%
t4
# Out:
# ((1, 2, 3, 4, 5), [1, 3, 5, 6, 7, 8])

# %%
del t4

# %%
t4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-7e8198522aa2> in <cell line: 1>()
# ----> 1 t4
#
# NameError: name 't4' is not defined

# %%
## sets

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s1 = {1,2,3,4,5}

# %%
type(s1)
# Out:
# set

# %%
s2 = {1,1,12,3,3,3,4,5,5,5,55,523,34,3,45,6,67}

# %%
# removed all duplicate - it will always try to store unique info and remove duplicate
s2
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %%
l = list(s2)

# %%
## convert set into lsit and vice versa

# %%
l = list(s2)

# %%
tuple(s2)
# Out:
# (1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55)

# %%
l
# Out:
# [1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55]

# %%
set(l)
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %%
#not allowed to store list in sets
s4 = {1,2,3,4,[1,2,3,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-dbf78102e3ba> in <cell line: 2>()
#       1 #not allowed to store list in sets
# ----> 2 s4 = {1,2,3,4,[1,2,3,4]}
#
# TypeError: unhashable type: 'list'

# %%
#will allow tuple into sets
s5 = {1,2,3,4, (1,2,3,4)}

# %%
s5
# Out:
# {(1, 2, 3, 4), 1, 2, 3, 4}

# %%
## set operations

# %%
s8 = {1,2,3,4}
s9 = {1,2,3,5}

# %%
s8.difference(s9)
# Out:
# {4}

# %%
s9.difference(s8)
# Out:
# {5}

# %%
# dictionary (Key-Value)

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {"name" : "sudh" , "emiil_id" : "ss@gmail.com" , "number" :234324}

# %%
type(d1)
# Out:
# dict

# %%
d1
# Out:
# {'name': 'sudh', 'emiil_id': 'ss@gmail.com', 'number': 234324}

# %%
# doesnt allow duplicate value


d2 = {"name" : "sudh" , "name" : "sudhanshu"}

# %%
d2
# Out:
# {'name': 'sudhanshu'}

# %%
# WONT ALLOW SPECIAL CHAR

# %%
d6 = {# : "abc"}
# Out:
#   File "<ipython-input-181-99df3a6c4fe9>", line 1
#     d6 = {# : "abc"}
#                     ^
# SyntaxError: incomplete input

# %%
d7 = {@ : "abc"}
# Out:
#   File "<ipython-input-182-c729364bd190>", line 1
#     d7 = {@ : "abc"}
#           ^
# SyntaxError: invalid syntax

# %%
# 1 KEY AND MULTIPLE PAIR

# %%
d12 = {"course_name" : ["data science master" , "web dev" ,"java with dsa and system Design"]}

# %%
d12
# Out:
# {'course_name': ['data science master',
#   'web dev',
#   'java with dsa and system Design']}

# %%
#data extraction from key

# %%
d15 = {"key" : {"name" : "sudhanshu" , "class" : "DSM"}}

# %%
type(d15['key'])
# Out:
# dict

# %%
# update dict

# %%
d19 = {"key1" : "value" , "key2" : "value2"}
d20 = {"key3" : "value3" , "key4" :"value4"}

# %%
(d19,d20)
# Out:
# ({'key1': 'value', 'key2': 'value2'}, {'key3': 'value3', 'key4': 'value4'})

# %%
d19.update(d20)

# %%
d19
# Out:
# {'key1': 'value', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
d20
# Out:
# {'key3': 'value3', 'key4': 'value4'}

# %%
d20.get("sudh")

# %%
d20.get("key3")
# Out:
# 'value3'

# %%
str ="Parth"

# %%
type(str)
# Out:
# str

# %%
str1 = 'I like'

# %%
str2 ="watching movies"

# %%
str1 + str2
# Out:
# 'I likewatching movies'

# %%
str1 +  str2
# Out:
#   File "<ipython-input-22-8ea9390b4587>", line 1
#     str1 + \n  str2
#             ^
# SyntaxError: unexpected character after line continuation character

# %%
print (str1) + '\n'+ str2
# Out:
# I like
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-de9a44c65ba0> in <cell line: 1>()
# ----> 1 print (str1) + '\n'+ str2
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
# Joining operation in stirng (Concatenation operations)

# %%
str1*3
# Out:
# 'I likeI likeI like'

# %%
str
# Out:
# str
